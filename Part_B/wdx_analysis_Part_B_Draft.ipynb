# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulSalamKagaji97/world_development_explorer/blob/main/Part_B/wdx_analysis_Part_B_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **How does population density, fossil fuel consumption, Renewable Energy Consumption impact on greenhouse gas emission?**
#
# *Abdul Salam Kagaji*
#
# *Data Science Master's Student, UMBC*
#
# *April 1, 2022*
#
# Global population growth leads to overpopulation, causing scarcity of natural resources of the Earth. Population is growth is influenced by multiple factors like evolved health care, better and safe urban infrastructures. It makes life unsustainable in areas with dense populations.
# Advanced innovations in the fields of science and health care have made life on Earth long-lasting. Despite these phenomenal results, it has also led to overpopulation which in turn affects the consumption of natural resources for energy generation. Modern innovations ranging from automobiles to semiconductor devices demand energy sources in form of electricity or fuels.
#
# Fossil fuels are the most prominent natural resources for the production of energy. Increasing populations require higher production of energy for everyday activities and this demands consumption of fossil fuels like coal and crude oil. Despite the production of hydroelectricity, the majority proportion of energy generated is from fossil fuels.
# Continued usage of energy and electronic devices have affected carbon emission leading to the greenhouse effect on Earth. Greenhouse gases cause global warming which disrupts the environmental conditions creating chaos that could lead to devastating situations.
#
# Lets analyze the effects of overpopulation, fossil fuel consumption, renewable energy consumption on greenhouse gas emissions with the data from the time period of 2010 to 2021.
#
# ## Approach
#
# **a.	Source of data & graphs:** THE WORLD DEVELOPMENT EXPLORER (https://www.worlddev.xyz/)
#
# **b.	Regions Compared:** East Asia & Pacific, Europe & central Asia, Latin America & Caribbean, Middle East & North Africa, North America, South Asia, Sub-Saharan Africa.
#
# **c.	Timeline :** 2010 to 2021
#
# **d.	Topics and Indicators:**
#
# -	**Urban Development** : Population density (people per sq. km of land area - EN.POP.DNST)
# - **Energy & Mining** : Renewable energy consumption (% of total final energy consumption - EG.FEC.RNEW.ZS)
# - **Energy & Mining** : Fossil fuel energy consumption (% of total - EG.USE.COMM.FO.ZS)
# - **Climate Change** : Total greenhouse gas emissions (kt of CO2 equivalent - EN.ATM.GHGT.KT.CE)
#
# ## Visual Analysis:

# %%
import pandas as pd
import plotly.express as px

# %%
URL = "https://raw.githubusercontent.com/abdulSalamKagaji97/world_development_explorer/main/Part_B/wdi_data_part_b.csv"

# %%
df = pd.read_csv(URL)
df.sample(10)
# Out:
#       Unnamed: 0  Year          value          indicator Country Code  \
# 5971        5971  2019      14.647442        EN.POP.DNST          NOR
# 734          734  2015   89510.000000  EN.ATM.GHGT.KT.CE          ISR
# 5905        5905  2019      18.910410        EN.POP.DNST          NZL
# 6491        6491  2012     142.688889        EN.POP.DNST          TON
# 6459        6459  2013     133.383936        EN.POP.DNST          THA
# 4937        4937  2016     143.200250        EN.POP.DNST          DNK
# 6544        6544  2010      34.376842        EN.POP.DNST          TCA
# 827          827  2018  112970.000000  EN.ATM.GHGT.KT.CE          KWT
# 6216        6216  2011      90.928761        EN.POP.DNST          SLE
# 4857        4857  2013      92.873306        EN.POP.DNST          CRI
#
#                   Country Name                      Region  \
# 5971                    Norway       Europe & Central Asia
# 734                     Israel  Middle East & North Africa
# 5905               New Zealand         East Asia & Pacific
# 6491                     Tonga         East Asia & Pacific
# 6459                  Thailand         East Asia & Pacific
# 4937                   Denmark       Europe & Central Asia
# 6544  Turks and Caicos Islands  Latin America & Caribbean
# 827                     Kuwait  Middle East & North Africa
# 6216              Sierra Leone         Sub-Saharan Africa
# 4857                Costa Rica  Latin America & Caribbean
#
#              Income Group    Lending Type
# 5971          High income  Not classified
# 734           High income  Not classified
# 5905          High income  Not classified
# 6491  Upper middle income             IDA
# 6459  Upper middle income            IBRD
# 4937          High income  Not classified
# 6544          High income  Not classified
# 827           High income  Not classified
# 6216           Low income             IDA
# 4857  Upper middle income            IBRD

# %%
df.indicator.unique()
# Out:
# array(['EN.ATM.GHGT.KT.CE', 'EG.USE.COMM.FO.ZS', 'EG.FEC.RNEW.ZS',
#        'EN.POP.DNST'], dtype=object)

# %% [markdown]
# ### Population distribution among regions:

# %%
df_population_density = df.query("indicator == 'EN.POP.DNST'")
df_population_density.sample(5)
# Out:
#       Unnamed: 0  Year        value    indicator Country Code  \
# 5352        5352  2013    46.957172  EN.POP.DNST          IRN
# 6565        6565  2020   393.066667  EN.POP.DNST          TUV
# 5296        5296  2012  6809.619048  EN.POP.DNST          HKG
# 5823        5823  2014    33.426832  EN.POP.DNST          MOZ
# 4397        4397  2015   165.942553  EN.POP.DNST          AND
#
#               Country Name                      Region         Income Group  \
# 5352    Iran, Islamic Rep.  Middle East & North Africa  Lower middle income
# 6565                Tuvalu         East Asia & Pacific  Upper middle income
# 5296  Hong Kong SAR, China         East Asia & Pacific          High income
# 5823            Mozambique         Sub-Saharan Africa            Low income
# 4397               Andorra       Europe & Central Asia          High income
#
#         Lending Type
# 5352            IBRD
# 6565             IDA
# 5296  Not classified
# 5823             IDA
# 4397  Not classified

# %%
df_population_region_group = df_population_density.groupby("Region").value.sum()
df_population_region_group = df_population_region_group.reset_index()
df_population_region_group
# Out:
#                        Region          value
# 0         East Asia & Pacific  431804.961155
# 1       Europe & Central Asia  319456.010751
# 2  Latin America & Caribbean    92435.011488
# 3  Middle East & North Africa   68586.107779
# 4               North America   13577.721557
# 5                  South Asia   44202.455145
# 6         Sub-Saharan Africa    53924.048330

# %%
df_pop_sorted = df_population_region_group.sort_values(by="value",ascending=False)
fig = px.bar(
    data_frame=df_pop_sorted,
    x = "Region", 
    y = "value",
    color = "Region",
    height = 600,
    labels={'value':'population density (group sum)'},
    template = "plotly_white"
    )
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d97fd08a-0d32-4115-a0c0-4a5b3109ac20" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d97fd08a-0d32-4115-a0c0-4a5b3109ac20")) {                    Plotly.newPlot(                        "d97fd08a-0d32-4115-a0c0-4a5b3109ac20",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>population density (group sum)=%{y}<extra></extra>","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[431804.961154834],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>population density (group sum)=%{y}<extra></extra>","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[319456.0107505101],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>population density (group sum)=%{y}<extra></extra>","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[92435.0114876576],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>population density (group sum)=%{y}<extra></extra>","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[68586.1077794842],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>population density (group sum)=%{y}<extra></extra>","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[53924.0483300528],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>population density (group sum)=%{y}<extra></extra>","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[44202.4551453837],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}<br>population density (group sum)=%{y}<extra></extra>","legendgroup":"North America","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[13577.7215569652],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor" ...

# %% [markdown]
# - From the distribution graph it is clearly seen that the population density of East Asia & Pacific region is the highest as compared to other western regions like North America and middle East & North Africa region, followed by Europe & central Asia with second highest population density.
# - Sub-Saharan Africa is the region with least population density.

# %% [markdown]
# ### Population Change between 2010 and 2021:

# %%
df_population_region_group_trend = df_population_density.groupby(["Year","Region"]).value.sum()
df_population_region_group_trend = df_population_region_group_trend.reset_index()
df_population_region_group_trend
fig = px.line(
    df_population_region_group_trend, 
    x="Year", 
    labels={"value":"Population Density (group sum)"},
    y="value",
    color="Region",
    height=600,
    title="Population density change"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0037e56e-1039-4341-a6ee-8c6562752483" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0037e56e-1039-4341-a6ee-8c6562752483")) {                    Plotly.newPlot(                        "0037e56e-1039-4341-a6ee-8c6562752483",                        [{"hovertemplate":"Region=East Asia & Pacific<br>Year=%{x}<br>Population Density (group sum)=%{y}<extra></extra>","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[37122.4200823207,37632.7413636023,38345.2749798801,38711.9250993376,39302.0963632276,39820.2134650565,40288.2172738161,40510.1160639398,39634.608547176496,40088.6819128024,40348.6660036744],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia<br>Year=%{x}<br>Population Density (group sum)=%{y}<extra></extra>","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[27940.3604993832,28180.519545118903,28438.8739118144,28690.950718825403,28931.6100624052,29160.6706467485,29363.729444148903,29555.163576243503,29562.4078251233,29733.2699442222,29898.454576476597],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean <br>Year=%{x}<br>Population Density (group sum)=%{y}<extra></extra>","legendgroup":"Latin America & Caribbean ","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[8047.3302894025,8132.2312713317,8200.8060065712,8291.719874876,8354.6126252492,8423.3639007247,8497.4305262784,8556.7751856367,8594.6285040348,8644.9781823414,8691.135121211],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa<br>Year=%{x}<br>Population Density (group sum)=%{y}<extra></extra>","legendgroup":"Middle East & North Africa","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[5494.6076475351,5628.4768832299,5755.9035921457,5887.5178129053,6029.6100055969,6171.7145106889,6338.8990671636,6520.1727402229,6721.908944048,6923.4499203642,7113.8466555837],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America<br>Year=%{x}<br>Population Density (group sum)=%{y}<extra></extra>","legendgroup":"North America","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"North America","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1243.6086023015,1233.5221983079,1238.1481472836,1242.1871023703998,1245.0179984612,1247.1381363825,1234.7903555266,1222.4520010581,1223.5494410301,1223.6603239325,1223.6472503108],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=South Asia<br>Year=%{x}<br>Population Density (group sum)=%{y}<extra></extra>","legendgroup":"South Asia","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"South Asia","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[3574.9358491574,3651.6591602712,3732.9603270556,3821.8520572126,3915.2256856321,4015.2112556098,4114.5535334607,4 ...

# %% [markdown]
# - The time series graph shows a gradual increase in population densities in all the regions with time and it is also seen that East Asia & Pacific has highest change in population density.

# %% [markdown]
# ### Fossil Fuel Consumption by region:

# %%
df_fossil_fuel_consumption = df.query("indicator == 'EG.USE.COMM.FO.ZS'")
df_fossil_fuel_consumption.sample(5)
# Out:
#       Unnamed: 0  Year      value          indicator Country Code  \
# 1797        1797  2013  68.826033  EG.USE.COMM.FO.ZS          BWA
# 2291        2291  2012  66.832868  EG.USE.COMM.FO.ZS          SVK
# 2015        2015  2013  98.958888  EG.USE.COMM.FO.ZS          IRN
# 2281        2281  2012  87.089408  EG.USE.COMM.FO.ZS          SRB
# 2382        2382  2011  79.554036  EG.USE.COMM.FO.ZS          UKR
#
#             Country Name                      Region         Income Group  \
# 1797            Botswana         Sub-Saharan Africa   Upper middle income
# 2291     Slovak Republic       Europe & Central Asia          High income
# 2015  Iran, Islamic Rep.  Middle East & North Africa  Lower middle income
# 2281              Serbia       Europe & Central Asia  Upper middle income
# 2382             Ukraine       Europe & Central Asia  Lower middle income
#
#         Lending Type
# 1797            IBRD
# 2291  Not classified
# 2015            IBRD
# 2281            IBRD
# 2382            IBRD

# %%
df_fossil_fuel_consumption = df_fossil_fuel_consumption.groupby(["Region"]).value.sum()
df_fossil_fuel_consumption = df_fossil_fuel_consumption.reset_index()
df_fossil_fuel_consumption
# Out:
#                        Region         value
# 0         East Asia & Pacific   6620.593711
# 1       Europe & Central Asia  19345.555666
# 2  Latin America & Caribbean    7896.366823
# 3  Middle East & North Africa   8107.266415
# 4               North America    944.731270
# 5                  South Asia   1328.998062
# 6         Sub-Saharan Africa    4254.209111

# %%
fig = px.pie(df_fossil_fuel_consumption, values='value', names='Region', title = "Fossil fuel consumption by region")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ef653abb-ac5f-4e0a-9744-babdc6782876" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef653abb-ac5f-4e0a-9744-babdc6782876")) {                    Plotly.newPlot(                        "ef653abb-ac5f-4e0a-9744-babdc6782876",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{label}<br>value=%{value}<extra></extra>","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[6620.5937112191,19345.5556655821,7896.3668231126,8107.2664145767,944.7312696919,1328.9980619721,4254.2091108077],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatt ...

# %% [markdown]
# - The above pie chart shows that the Europe & Central Asia has the highest fossil fuel consumption recorded with a total of 39.9% followed by Middle East & North Africa.

# %% [markdown]
# ### Renewable Energy Consumption by region:

# %%
df_renewable_energy_consumption = df.query("indicator == 'EG.FEC.RNEW.ZS'")
df_renewable_energy_consumption.sample(5)
# Out:
#       Unnamed: 0  Year      value       indicator Country Code  \
# 4343        4343  2014  80.775002  EG.FEC.RNEW.ZS          ZWE
# 3924        3924  2018  21.144699  EG.FEC.RNEW.ZS          SRB
# 3962        3962  2011  10.357100  EG.FEC.RNEW.ZS          SVK
# 3123        3123  2018  11.473600  EG.FEC.RNEW.ZS          GRL
# 2446        2446  2016  39.587299  EG.FEC.RNEW.ZS          ALB
#
#          Country Name                 Region         Income Group  \
# 4343         Zimbabwe    Sub-Saharan Africa   Lower middle income
# 3924           Serbia  Europe & Central Asia  Upper middle income
# 3962  Slovak Republic  Europe & Central Asia          High income
# 3123        Greenland  Europe & Central Asia          High income
# 2446          Albania  Europe & Central Asia  Upper middle income
#
#         Lending Type
# 4343           Blend
# 3924            IBRD
# 3962  Not classified
# 3123  Not classified
# 2446            IBRD

# %%
df_renewable_energy_consumption = df_renewable_energy_consumption.groupby(["Region"]).value.sum()
df_renewable_energy_consumption = df_renewable_energy_consumption.reset_index()
df_renewable_energy_consumption
# Out:
#                        Region         value
# 0         East Asia & Pacific   6426.957890
# 1       Europe & Central Asia  10159.765580
# 2  Latin America & Caribbean    7438.931716
# 3  Middle East & North Africa    886.370204
# 4               North America    285.972101
# 5                  South Asia   3268.956908
# 6         Sub-Saharan Africa   27506.435389

# %%
fig = px.pie(df_renewable_energy_consumption, values='value', names='Region', title = "Renewable Energy consumption by region")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="863e334c-2d20-4069-aefc-33ca32726132" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("863e334c-2d20-4069-aefc-33ca32726132")) {                    Plotly.newPlot(                        "863e334c-2d20-4069-aefc-33ca32726132",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{label}<br>value=%{value}<extra></extra>","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[6426.9578899782,10159.7655795033,7438.9317158349995,886.3702036122,285.9721006752,3268.9569084646,27506.4353889229],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"sc ...

# %% [markdown]
# - In contrast to the fossil fuel consumption graph, Sub-Saharan Africa has the highest renewable energy consumption when compared to all the other regions with a total of 49.1% and North America has the least renewable Energy Consumption records

# %% [markdown]
# ### Greenhouse Gas Emission by region:

# %%
df_greenhouse_gas_emission = df.query("indicator == 'EN.ATM.GHGT.KT.CE'")
df_greenhouse_gas_emission.sample(5)
# Out:
#       Unnamed: 0  Year    value          indicator Country Code  \
# 556          556  2017   7530.0  EN.ATM.GHGT.KT.CE          GAB
# 566          566  2018   2790.0  EN.ATM.GHGT.KT.CE          GMB
# 1366        1366  2017  40480.0  EN.ATM.GHGT.KT.CE          SVK
# 598          598  2014  89910.0  EN.ATM.GHGT.KT.CE          GRC
# 1715        1715  2015  31280.0  EN.ATM.GHGT.KT.CE          ZWE
#
#          Country Name                 Region         Income Group  \
# 556             Gabon    Sub-Saharan Africa   Upper middle income
# 566       Gambia, The    Sub-Saharan Africa            Low income
# 1366  Slovak Republic  Europe & Central Asia          High income
# 598            Greece  Europe & Central Asia          High income
# 1715         Zimbabwe    Sub-Saharan Africa   Lower middle income
#
#         Lending Type
# 556             IBRD
# 566              IDA
# 1366  Not classified
# 598   Not classified
# 1715           Blend

# %%
df_greenhouse_gas_emission = df_greenhouse_gas_emission.groupby(["Region"]).value.sum()
df_greenhouse_gas_emission = df_greenhouse_gas_emission.reset_index()
df_greenhouse_gas_emission
# Out:
#                        Region        value
# 0         East Asia & Pacific  149743170.0
# 1       Europe & Central Asia   77151910.0
# 2  Latin America & Caribbean    28464090.0
# 3  Middle East & North Africa   27901280.0
# 4               North America   60954130.0
# 5                  South Asia   33008140.0
# 6         Sub-Saharan Africa    19835920.0

# %%
fig = px.pie(df_greenhouse_gas_emission, values='value', names='Region', title = "Greenhouse gas emission by region")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d6486932-e64d-4822-afc7-aa5337f7acae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6486932-e64d-4822-afc7-aa5337f7acae")) {                    Plotly.newPlot(                        "d6486932-e64d-4822-afc7-aa5337f7acae",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Region=%{label}<br>value=%{value}<extra></extra>","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[149743170.0,77151910.0,28464090.0,27901280.0,60954130.0,33008140.0,19835920.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outli ...

# %% [markdown]
# - A surprisingly high contribution towards greenhouse gas emission is seen by the East Asia & Pacific with a total of 37.7%.

# %% [markdown]
# ### Relation between population density,fossil fuel consumption and greenhouse gas emission:

# %%
df_relations = df.groupby(["indicator","Region"]).value.sum()
df_relations = df_relations.reset_index().query("indicator != 'EG.FEC.RNEW.ZS'")
df_relations




data = []
columns = df_relations.indicator.unique()
for region in df.Region.unique():
    li = []
    li.append(region)
    for indicator in df_relations.indicator.unique():
        dff = df_relations.query(f"Region == '{region}'").query(f"indicator == '{indicator}'")
        try:
            li.append(float(dff.value))
        except:
          pass
    data.append(li)
df_population_fossil_fuel_greenhouse_gas_relation = pd.DataFrame(data)
df_population_fossil_fuel_greenhouse_gas_relation.columns = ["Region", *columns]
df_population_fossil_fuel_greenhouse_gas_relation
# Out:
#                        Region  EG.USE.COMM.FO.ZS  EN.ATM.GHGT.KT.CE  \
# 0                  South Asia        1328.998062         33008140.0
# 1       Europe & Central Asia       19345.555666         77151910.0
# 2  Middle East & North Africa        8107.266415         27901280.0
# 3         Sub-Saharan Africa         4254.209111         19835920.0
# 4  Latin America & Caribbean         7896.366823         28464090.0
# 5         East Asia & Pacific        6620.593711        149743170.0
# 6               North America         944.731270         60954130.0
#
#      EN.POP.DNST
# 0   44202.455145
# 1  319456.010751
# 2   68586.107779
# 3   53924.048330
# 4   92435.011488
# 5  431804.961155
# 6   13577.721557

# %%
df_population_fossil_fuel_greenhouse_gas_relation.columns = ["Region", "fossil_fuel_consumption", 'greenhouse_gas_emission','populaiton_density']
df_population_fossil_fuel_greenhouse_gas_relation
# Out:
#                        Region  fossil_fuel_consumption  \
# 0                  South Asia              1328.998062
# 1       Europe & Central Asia             19345.555666
# 2  Middle East & North Africa              8107.266415
# 3         Sub-Saharan Africa               4254.209111
# 4  Latin America & Caribbean               7896.366823
# 5         East Asia & Pacific              6620.593711
# 6               North America               944.731270
#
#    greenhouse_gas_emission  populaiton_density
# 0               33008140.0        44202.455145
# 1               77151910.0       319456.010751
# 2               27901280.0        68586.107779
# 3               19835920.0        53924.048330
# 4               28464090.0        92435.011488
# 5              149743170.0       431804.961155
# 6               60954130.0        13577.721557

# %%
fig = px.scatter(df_population_fossil_fuel_greenhouse_gas_relation, 
                 x="populaiton_density",
                 y="fossil_fuel_consumption", 
                 color="Region",
                 size='greenhouse_gas_emission',
                 labels={"populaiton_density":"Population Density (group sum)","fossil_fuel_consumption":"Fossil Fuel Energy Consumption"},
                 height=600,
                 title="Relation between population density,fossil fuel consumption and greenhouse gas emission")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fbcbddef-85c4-4ab6-b109-c97503fc07cb" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbcbddef-85c4-4ab6-b109-c97503fc07cb")) {                    Plotly.newPlot(                        "fbcbddef-85c4-4ab6-b109-c97503fc07cb",                        [{"hovertemplate":"Region=South Asia<br>Population Density (group sum)=%{x}<br>Fossil Fuel Energy Consumption=%{y}<br>greenhouse_gas_emission=%{marker.size}<extra></extra>","legendgroup":"South Asia","marker":{"color":"#636efa","size":[33008140.0],"sizemode":"area","sizeref":374357.925,"symbol":"circle"},"mode":"markers","name":"South Asia","orientation":"v","showlegend":true,"x":[44202.4551453837],"xaxis":"x","y":[1328.9980619721],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia<br>Population Density (group sum)=%{x}<br>Fossil Fuel Energy Consumption=%{y}<br>greenhouse_gas_emission=%{marker.size}<extra></extra>","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[77151910.0],"sizemode":"area","sizeref":374357.925,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[319456.0107505101],"xaxis":"x","y":[19345.5556655821],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa<br>Population Density (group sum)=%{x}<br>Fossil Fuel Energy Consumption=%{y}<br>greenhouse_gas_emission=%{marker.size}<extra></extra>","legendgroup":"Middle East & North Africa","marker":{"color":"#00cc96","size":[27901280.0],"sizemode":"area","sizeref":374357.925,"symbol":"circle"},"mode":"markers","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[68586.1077794842],"xaxis":"x","y":[8107.2664145767],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Sub-Saharan Africa <br>Population Density (group sum)=%{x}<br>Fossil Fuel Energy Consumption=%{y}<br>greenhouse_gas_emission=%{marker.size}<extra></extra>","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#ab63fa","size":[19835920.0],"sizemode":"area","sizeref":374357.925,"symbol":"circle"},"mode":"markers","name":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"x":[53924.0483300528],"xaxis":"x","y":[4254.2091108077],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean <br>Population Density (group sum)=%{x}<br>Fossil Fuel Energy Consumption=%{y}<br>greenhouse_gas_emission=%{marker.size}<extra></extra>","legendgroup":"Latin America & Caribbean ","marker":{"color":"#FFA15A","size":[28464090.0],"sizemode":"area","sizeref":374357.925,"symbol":"circle"},"mode":"markers","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[92435.0114876576],"xaxis":"x","y":[7896.3668231126],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=East Asia & Pacific<br>Population Density (group sum)=%{x}<br>Fossil Fuel Energy Consumption=%{y}<br>greenhouse_gas_emission=%{marker.size}<extra></extra>","legendgroup":"East Asia & Pacific","marker":{"color":"#19d3f3","size":[149743170.0],"sizemode":"area","sizeref":374357.925,"symbol":"circle"},"mode":"markers","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[431804.961154834],"xaxis":"x","y":[6620.5937112191],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America<br>Population Density (group sum)=%{x}<br>Fossil Fuel Energy Consumption=%{y}<br>greenhouse_gas_emission=%{marker.size}<extra></extra>","legendgroup":"North America","marker":{"color":"#FF6692","size":[60954130.0],"sizemode":"area","sizeref":374357.925,"symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[13577.7215569652],"xaxis":"x","y":[944.7312696919],"yaxis":"y","type":"scatter"}],    ...

# %% [markdown]
# - The graph shows how fossil fuel consumption directly impacts the emission of greenhouse gases despite population density.
# North America, despite its low population density has a very high volume of greenhouse gas emission. And East Asia & pacific with comparably less greenhouse gas emission even with highest population density.

# %% [markdown]
# ### Relation between population density, renewable energy consumption and greenhouse gas emission
